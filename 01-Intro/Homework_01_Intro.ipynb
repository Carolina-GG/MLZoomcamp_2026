# %% [markdown]
# HOMEWORK 1

# %%
# Dependencies

import pandas as pd
import numpy as np

# %% [markdown]
# Getting the data

# %%
df = pd.read_csv("https://raw.githubusercontent.com/DataTalksClub/machine-learning-zoomcamp/main/cohorts/2026/data/car_fuel_efficiency_2026.csv")
df.head()
# Out:
#    model_year  origin fuel_type         drivetrain  num_doors  \
# 0        2006  Europe  Gasoline  Front-wheel drive          4
# 1        2008  Europe    Diesel  Front-wheel drive          4
# 2        1996    Asia  Gasoline  Front-wheel drive          5
# 3        1989  Europe  Gasoline  Front-wheel drive          4
# 4        1994     USA    Diesel  Front-wheel drive          3
#
#    engine_displacement  num_cylinders  horsepower  vehicle_weight  \
# 0                 2180              6       243.0            3870
# 1                 2390              6       272.0            4210
# 2                 2320              6       267.0            4240
# 3                 2130              6       258.0            4490
# 4                 2580              7       304.0            4510
#
#    acceleration  fuel_efficiency_mpg
# 0           NaN                 31.9
# 1           NaN                 31.3
# 2          17.3                 27.5
# 3          18.7                 28.5
# ...

# %% [markdown]
# Q1. Pandas version

# %%
pd.__version__
# Out:
# '2.2.3'

# %% [markdown]
# Q2. Records count

# %%
len(df)
# Out:
# 10000

# %% [markdown]
# Q3. Fuel types

# %%
df['fuel_type'].unique() # There are three types of fuel
# Out:
# array(['Gasoline', 'Diesel', 'Hybrid'], dtype=object)

# %% [markdown]
# Q4. Missing values

# %%
df.isnull().sum() # There are two columns with missing values
# Out:
# model_year               0
# origin                   0
# fuel_type                0
# drivetrain               0
# num_doors                0
# engine_displacement      0
# num_cylinders            0
# horsepower             877
# vehicle_weight           0
# acceleration           264
# fuel_efficiency_mpg      0
# dtype: int64

# %% [markdown]
# Q5. Max fuel efficiency

# %%
df['fuel_efficiency_mpg'].max()
# Out:
# 41.2

# %% [markdown]
# Q6. Median value of horsepower

# %%
df['horsepower'].median() # Median of the variable Horsepower
# Out:
# 254.0

# %%
df['horsepower'].mode() # Most frequent value
# Out:
# 0    252.0
# Name: horsepower, dtype: float64

# %%
df['horsepower'] = df['horsepower'].fillna(df['horsepower'].mode())

# %%
df['horsepower'].median() # New median after fillna
# Out:
# 254.0

# %% [markdown]
# Q7. Sum of weights

# %%
df_asia = df[df['origin'] == 'Asia'] # Only Asian cars

X = df_asia[['vehicle_weight', 'model_year']].head(7).to_numpy()
# Selected variables, first 7 observations, creating a np array

XTX = X.T.dot(X)
XTX_inv = np.linalg.inv(XTX)

y = np.array([1100, 1300, 800, 900, 1000, 1100, 1200])

w = XTX_inv.dot(X.T).dot(y)

print(w.sum()) # Sum of all the elements of the result
# Out:
# 0.36919696904925486
